# %% [markdown]
# # <div style="background-color:#000080;font-family:newtimeroman;color:#DCB233;font-size:130%;text-align:center;border-radius:10px 10px;">✍️ Évaluation Statistique: Projet Statistique - SDA2024</div>

# %% [markdown]
# <div style="text-align:center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/9/99/Logo_of_the_Pantheon-Sorbonne_University_in_Paris.png" alt="SDA2024" style="width:840px;height:269px;">
# </div>

# %% [markdown]
# <b><u>Réalisé(e)s Par :</u></b>

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                        |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **M. MEJRI Salam** | Mejri.Salam@gmail.com | <a href="https://www.linkedin.com/in/salam-mejri/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> | <a href="https://github.com/mslouma88" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white" alt="GitHub Badge"></a> | <a href="https://www.kaggle.com/salammejri" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white" alt="Kaggle Badge"></a> |

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                        |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **Mme BENAMOR Nesrine**  | Nesrinebenamor518@gmail.com | <a href="https://www.linkedin.com/in/nesrine-benamor-506659293/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> | <a href="https://github.com/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white" alt="GitHub Badge"></a> | <a href="https://www.kaggle.com/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white" alt="Kaggle Badge"></a> |

# %% [markdown]
# <b><u>Encadrés Par:</u></br>

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|
# | **M. Marc-Arthur**  | Marc-Arthur.Diaye@univ-paris1.fr | <a href="https://www.linkedin.com/in/marc-arthur-diaye-95796125/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> |

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|
# | **M. BIGROFF Alexis**  | Alexis.Bogroff@univ-paris1.fr | <a href="https://www.linkedin.com/in/alexisbogroff/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> |

# %% [markdown]
# <a id='TabMatiere'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Tables de matières ⤵</div>

# %% [markdown]
# * [Importation des bibliotheques](#Importation)
# * [Chargement et affichage de données](#Chargement)
# * [Description de données](#Description)
# * [Inégalités de Décrochage Scolaire Entre les Collèges Français](#Question1)
# * [Taille du Collège et Taux de Décrochage: Une Relation Causale?](#Question2)
# * [Différences de Décrochage Scolaire Entre Garçons et Filles](#Question3)
# * [Variations Régionales du Décrochage Scolaire en France](#Question4)
# * [Collège Public vs. Privé: Un Impact sur le Décrochage Scolaire](#Question5)

# %% [markdown]
# <a id='Importation'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Importation des Bibliothéques 📊</div>

# %%
#importation des librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id='Chargement'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Chargement et affichage des données ⏳</div>

# %% [markdown]
# **➤ Dataset:** </br>
# Les données sont
# disponible sur le site du gouvernement : https://data.education.gouv.fr/explore/dataset/fr-en-collegeeffectifs-niveau-sexe-lv/.

# %%
# Le chemin vers du fichier CSV
chemin_fichier_csv = r'data\fr-en-college-effectifs-niveau-sexe-lv.csv'

# Chargement du fichier CSV et affichage du DataFrame
df = pd.read_csv(chemin_fichier_csv, delimiter=';')
df
# Out:
#        Rentrée scolaire                   Région Académie      Département  \
# 0                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 1                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 2                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 3                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 4                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# ...                 ...                      ...      ...              ...
# 32977              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32978              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32979              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32980              2020                 BRETAGNE   RENNES         MORBIHAN
# 32981              2020                 BRETAGNE   RENNES         MORBIHAN
#
# ...

# %% [markdown]
# <a id='Description'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Description des données  🔍</div>

# %%
print('➤ Notre jeu de données contient', df.shape[0], 'lignes et', df.shape[1], 'colonnes.')
# Out:
# ➤ Notre jeu de données contient 32982 lignes et 76 colonnes.

# %%
df.columns
# Out:
# Index(['Rentrée scolaire', 'Région', 'Académie', 'Département', 'Commune',
#        'Numéro du collège', 'Dénomination principale', 'Patronyme', 'Secteur',
#        'REP', 'REP +', 'Nombre d'élèves total',
#        'Nombre d'élèves total hors Segpa hors ULIS',
#        'Nombre d'élèves total Segpa', 'Nombre d'élèves total ULIS',
#        '6èmes total', '6èmes hors Segpa hors ULIS', '6èmes Segpa',
#        '6èmes ULIS', '6èmes filles', '6èmes garçons', '6èmes LV1 allemand',
#        '6èmes LV1 anglais', '6èmes LV1 espagnol', '6èmes LV1 autres langues',
#        '6èmes LV2 allemand', '6èmes LV2 anglais', '6èmes LV2 espagnol',
#        '6èmes LV2 italien', '6ème LV2 autres langues', '5èmes total',
#        '5èmes hors Segpa hors ULIS', '5èmes Segpa', '5èmes ULIS',
#        '5èmes filles', '5èmes garçons', '5èmes LV1 allemand',
#        '5èmes LV1 anglais', '5èmes LV1 espagnol', '5èmes LV1 autres langues',
#        '5èmes LV2 allemand', '5èmes LV2 anglais', '5èmes LV2 espagnol',
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Rentrée scolaire                   Région Académie      Département  \
# 0                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 1                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 2                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 3                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# 4                  2019  AUVERGNE-ET-RHONE-ALPES     LYON            RHONE
# ...                 ...                      ...      ...              ...
# 32977              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32978              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32979              2020                 BRETAGNE   RENNES  ILLE-ET-VILAINE
# 32980              2020                 BRETAGNE   RENNES         MORBIHAN
# 32981              2020                 BRETAGNE   RENNES         MORBIHAN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32982 entries, 0 to 32981
# Data columns (total 76 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Rentrée scolaire                            32982 non-null  int64
#  1   Région                                      32982 non-null  object
#  2   Académie                                    32982 non-null  object
#  3   Département                                 32982 non-null  object
#  4   Commune                                     32982 non-null  object
#  5   Numéro du collège                           32982 non-null  object
#  6   Dénomination principale                     32982 non-null  object
#  7   Patronyme                                   32927 non-null  object
#  8   Secteur                                     32982 non-null  object
#  9   REP                                         32982 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                               count          mean  \
# Rentrée scolaire                            32982.0   2020.501364
# REP                                         32982.0      0.089655
# REP +                                       32982.0      0.044085
# Nombre d'élèves total                       32982.0    413.304469
# Nombre d'élèves total hors Segpa hors ULIS  32982.0    397.448578
# ...                                             ...           ...
# 3èmes LV2 anglais                           32982.0      3.875508
# 3èmes LV2 espagnol                          32982.0     75.133922
# 3èmes LV2 italien                           32982.0      5.534322
# 3èmes LV2 autres langues                    32982.0      1.409041
# Code postal                                 32862.0  54418.519567
#
#                                                      std     min      25%  \
# Rentrée scolaire                                1.118186  2019.0   2020.0
# ...

# %%
#type des variables
df.dtypes
# Out:
# Rentrée scolaire              int64
# Région                       object
# Académie                     object
# Département                  object
# Commune                      object
#                              ...
# 3èmes LV2 anglais             int64
# 3èmes LV2 espagnol            int64
# 3èmes LV2 italien             int64
# 3èmes LV2 autres langues      int64
# Code postal                 float64
# Length: 76, dtype: object

# %% [markdown]
# <a id='Nettoyage'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Nettoyage des données 🧹</div>

# %%
#les valeurs manquantes
df.isnull().sum()
# Out:
# Rentrée scolaire              0
# Région                        0
# Académie                      0
# Département                   0
# Commune                       0
#                            ...
# 3èmes LV2 anglais             0
# 3èmes LV2 espagnol            0
# 3èmes LV2 italien             0
# 3èmes LV2 autres langues      0
# Code postal                 120
# Length: 76, dtype: int64

# %%
# Afficher les colonnes contenant des valeurs manquantes
colonnes_valeurs_manquantes = df.columns[df.isnull().any()]
print("les colonnes qui contiennent des valeurs manquante sont :",colonnes_valeurs_manquantes)
# Out:
# les colonnes qui contiennent des valeurs manquante sont : Index(['Patronyme', 'Code postal'], dtype='object')

# %%
df['Code postal'].isnull().sum()
# Out:
# 120

# %%
df['Patronyme'].isnull().sum()
# Out:
# 55

# %%
#les doublons
print("les doublons :",df.duplicated().sum())
# Out:
# les doublons : 0

# %% [markdown]
# <a id='Analyse'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Analyse des données 🔬</div>

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# ➤ Pour chaque question, nous allons appliquer des méthodes statistiques appropriées en veillant à vérifier les hypothèses sous-jacentes</p></div>

# %%
#on selectionne toutes les colonnes qu'on va les utiliser pour répondre à nos questions
# Liste des colonnes à sélectionner
colonnes_a_selectionner = ['Rentrée scolaire','Numéro du collège',"Nombre d'élèves total", '6èmes total','3èmes total','6èmes filles','6èmes garçons','3èmes filles','3èmes garçons','Région', 'Secteur']

# Sélection des colonnes
df_selection = df[colonnes_a_selectionner]
df_selection
# Out:
#        Rentrée scolaire Numéro du collège  Nombre d'élèves total  6èmes total  \
# 0                  2019          0691664J                    779          208
# 1                  2019          0692390Y                     59           15
# 2                  2019          0693093M                    450           93
# 3                  2019          0694296V                    398          124
# 4                  2019          0690117C                    432          115
# ...                 ...               ...                    ...          ...
# 32977              2020          0352071L                    159           38
# 32978              2020          0350780H                    892          212
# 32979              2020          0350887Z                    231           49
# 32980              2020          0561399S                    315           80
# 32981              2020          0560136U                    655          159
#
# ...

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# Avant de commencer notre analyse, on doit vérifier si nos données suivent une loi normale car de nombreux tests paramétriques (comme le test t de Student ou l'ANOVA) supposent que les données suivent une distribution normale. Si cette hypothèse est violée, les résultats de ces tests peuvent être invalides ou trompeurs. En vérifiant la normalité, on s'assure que les conditions nécessaires pour obtenir des conclusions fiables à partir des tests statistiques sont respectées.</p></div>

# %%
# Générer des données normalement distribuées
np.random.seed(0)
df_selection= np.random.normal(loc=0, scale=1, size=7042)
# Créer un Q-Q plot
stats.probplot(df_selection, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Quantiles théoriques')
plt.ylabel('Quantiles observés')
plt.show()

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
#     <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# ➜ <b>Points alignés avec la ligne diagonale :</b> Cela suggère que les données suivent approximativement une distribution normale. Les déviations mineures peuvent être attribuées à la variabilité des échantillons.
#     </p></div>

# %% [markdown]
# <a id='Question1'></a>
# ### <div style="background-color:#C8AD7F;font-family:newtimeroman;color:#333333;font-size:150%;text-align:center;border-radius:10px 10px;">Certains collèges ont t'ils davantage de décrochages scolaire que d'autres ? </div>

# %% [markdown]
# <b>Réduction du nombre d'élèves entre la 6e et la 3e:</b>
# * Calcul du taux de décrochage : (Effectif en 6e−Effectif en 3e)/Effectif en 6e
# * Tests statistiques : ANOVA pour comparer les taux de décrochage entre les collèges.

# %%
colonnes_a_selectionner = ['Rentrée scolaire','Numéro du collège',"Nombre d'élèves total", '6èmes total','3èmes total','6èmes filles','6èmes garçons','3èmes filles','3èmes garçons','Région', 'Secteur']
df_selection = df[colonnes_a_selectionner]
# Calculer le taux de décrochage pour chaque collège pour les différentes années
df_selection['taux_decrochage'] = (df_selection['6èmes total'] -df_selection['3èmes total']) / df_selection['6èmes total']*100
df_selection
# Out:
#        Rentrée scolaire Numéro du collège  Nombre d'élèves total  6èmes total  \
# 0                  2019          0691664J                    779          208
# 1                  2019          0692390Y                     59           15
# 2                  2019          0693093M                    450           93
# 3                  2019          0694296V                    398          124
# 4                  2019          0690117C                    432          115
# ...                 ...               ...                    ...          ...
# 32977              2020          0352071L                    159           38
# 32978              2020          0350780H                    892          212
# 32979              2020          0350887Z                    231           49
# 32980              2020          0561399S                    315           80
# 32981              2020          0560136U                    655          159
#
# ...

# %%
# La moyenne du taux de décrochage par collège
décrochage_collège= df_selection.groupby('Numéro du collège')['taux_decrochage'].mean()
décrochage_collège=décrochage_collège.reset_index()
décrochage_collège
# Out:
#      Numéro du collège  taux_decrochage
# 0             0010001W             -inf
# 1             0010002X        -4.837381
# 2             0010005A        10.753985
# 3             0010006B             -inf
# 4             0010008D        -4.263831
# ...                ...              ...
# 8332          9760363R             -inf
# 8333          9760368W         8.274722
# 8334          9760369X        -1.975225
# 8335          9760371Z        14.252012
# 8336          9760379H        -1.445314
#
# [8337 rows x 2 columns]

# %%
 #Filtrer et supprimer les lignes où 'taux_decrochage en %' est égal à -inf
décrochage_collège = décrochage_collège[décrochage_collège['taux_decrochage'] != -np.inf]
décrochage_collège
# Out:
#      Numéro du collège  taux_decrochage
# 1             0010002X        -4.837381
# 2             0010005A        10.753985
# 4             0010008D        -4.263831
# 5             0010018P         2.242711
# 7             0010022U        15.065210
# ...                ...              ...
# 8331          9760357J       -80.352980
# 8333          9760368W         8.274722
# 8334          9760369X        -1.975225
# 8335          9760371Z        14.252012
# 8336          9760379H        -1.445314
#
# [7043 rows x 2 columns]

# %%
df_selec=décrochage_collège
df_selec.reset_index()
df_selec = df_selec[df_selec['taux_decrochage'] >= 0]

# %%
# Sélection aléatoire de 10 collèges
college_aleatoires = np.random.choice(df_selec.index, 10, replace=False)
# Extraction des taux de décrochage pour ces collèges
decrochage_selection = df_selec.loc[college_aleatoires]

# %%
decrochage_selection
# Out:
#      Numéro du collège  taux_decrochage
# 5143          0671691Z         6.174838
# 7422          0921012A         2.756482
# 4173          0590164H         2.032058
# 2333          0342078Z         5.944833
# 7570          0930906E        10.247486
# 3998          0570223H        13.854222
# 6582          0790063P        13.900870
# 4481          0600012M         7.239045
# 3644          0512014M         4.913874
# 5193          0672194W         1.519750

# %%
# Création du graphique
plt.figure(figsize=(10, 6))
sns.barplot(x=decrochage_selection['Numéro du collège'], y=decrochage_selection['taux_decrochage'], palette='viridis')
plt.xlabel('Numéro du collège')
plt.ylabel('Taux de décrochage moyen')
plt.title('Taux de décrochage moyen pour 10 collèges sélectionnés au hasard')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Test Statistique - ANOVA

# %% [markdown]
# * <b>Test Statistique - ANOVA</b></br>
# Utilisons une ANOVA pour comparer les taux de décrochage entre les collèges. L'ANOVA nous permet de déterminer si les différences observées entre les groupes sont statistiquement significatives.

# %% [markdown]
# * <b>Hypothèses pour l'ANOVA</b></br>
# <u>Hypothèse nulle (H0) :</u> Les taux de décrochage moyens sont égaux pour tous les collèges.</br>
# <u>Hypothèse alternative (H1) :</u> Au moins un collège a un taux de décrochage moyen différent.</br>

# %% [markdown]
# ### Vérification des Hypothèses

# %%
collège_dc = df_selection[df_selection['taux_decrochage'] != -np.inf]
collège_dc = df_selection[ df_selection['taux_decrochage'] >= 0]

# %%
groupes = [collège_dc[collège_dc['Numéro du collège'] == nom]['taux_decrochage']
for nom in collège_dc['Numéro du collège'].unique()]
# Effectuer l'ANOVA
f_value, p_value = stats.f_oneway(*groupes)
print('Résultats de l\'ANOVA :')
print('F-value:', f_value)
print('p-value:', p_value)
# Out:
# Résultats de l'ANOVA :
# F-value: 2.6594149676538548
# p-value: 0.0

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
# <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
#     <b><u>Résultat</u></b></br>
#
# <b>F-value :</b></br>
# La F-value est une statistique qui mesure la variance entre les groupes par rapport à la variance au sein des groupes. Une valeur F plus élevée indique une plus grande différence entre les moyennes des groupes.</br>
#
# <b>p-value :</b></br>
# Une p-value de 0.0 indique une probabilité extrêmement faible que les différences observées entre les taux de décrochage des collèges soient dues au hasard. En pratique, une p-value aussi faible est arrondie à zéro, ce qui signifie que nous avons des preuves extrêmement solides contre l'hypothèse nulle.
#
# </p></div>

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
# <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# ➜<b>Conclusion :</b></br>
# <u>Rejet de l'hypothèse nulle (H0) :</u> Étant donné que la p-value est bien inférieure au seuil de signification communément utilisé (0.05), nous rejetons l'hypothèse nulle.</br>
# Différences entre les collèges : Il y a des preuves statistiques significatives pour dire que les taux de décrochage moyens diffèrent entre les collèges. Cela signifie qu'au moins un collège a un taux de décrochage moyen différent des autres.
#
# </p></div>

# %% [markdown]
# <a id='Question2'></a>
# ### <div style="background-color:#C8AD7F;font-family:newtimeroman;color:#333333;font-size:150%;text-align:center;border-radius:10px 10px;">Cette tendance a-t-elle un lien avec la taille du collège ? 🎓</div>

# %% [markdown]
# ➤ On va examiner la relation entre la taille des collèges (nombre d'élèves) et le taux de décrochage.

# %% [markdown]
# <b>Visualisation de la Relation:</b>
# Avant d'appliquer des tests statistiques, visualisons la relation entre la taille du collège et le taux de décrochage.

# %%
collège=df_selection.groupby('Numéro du collège').agg({"Nombre d'élèves total":'mean','taux_decrochage':'mean'})
collège
# Out:
#                    Nombre d'élèves total  taux_decrochage
# Numéro du collège
# 0010001W                           27.25             -inf
# 0010002X                          803.25        -4.837381
# 0010005A                          576.25        10.753985
# 0010006B                           21.50             -inf
# 0010008D                          722.50        -4.263831
# ...                                  ...              ...
# 9760363R                           24.00             -inf
# 9760368W                         1479.25         8.274722
# 9760369X                         1827.75        -1.975225
# 9760371Z                         1203.50        14.252012
# 9760379H                          726.75        -1.445314
#
# [8337 rows x 2 columns]

# %%
#Filtre et suppression des lignes où 'taux_decrochage ' est égal à -inf ou il a une valeur <0
collège = collège[collège['taux_decrochage'] != -np.inf]
collège = collège[collège['taux_decrochage'] >= 0]
collège
# Out:
#                    Nombre d'élèves total  taux_decrochage
# Numéro du collège
# 0010005A                          576.25        10.753985
# 0010018P                          523.00         2.242711
# 0010022U                          443.75        15.065210
# 0010024W                          724.50         5.641208
# 0010025X                          298.75        20.134327
# ...                                  ...              ...
# 9760244L                         1838.75         1.098803
# 9760245M                         1768.75         4.697932
# 9760314M                         1447.00         4.658264
# 9760368W                         1479.25         8.274722
# 9760371Z                         1203.50        14.252012
#
# [4388 rows x 2 columns]

# %%
# Scatter plot pour visualiser la relation entre la taille du collège et le taux de décrochage
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Nombre d'élèves total", y='taux_decrochage', data=collège)
plt.title('Relation entre la Taille du Collège et le Taux de Décrochage')
plt.xlabel('Nombre Total d\'Élèves')
plt.ylabel('Taux de Décrochage')
plt.show()

# %% [markdown]
# #### Test de Corrélation de Pearson

# %% [markdown]
# Le test de corrélation de Pearson mesure la force et la direction de la relation linéaire entre deux variables continues.</br>
# Hypothèses du Test de Corrélation de Pearson :</br>
# <u>Hypothèse nulle (H0) :</u> Il n'y a pas de corrélation linéaire entre le nombre d'élèves total et le taux de décrochage (r = 0).</br>
# <u>Hypothèse alternative (H1) :</u> Il existe une corrélation linéaire entre le nombre d'élèves total et le taux de décrochage (r ≠ 0).

# %%
# Calcul de la corrélation
correlation, p_value = stats.pearsonr(collège["Nombre d'élèves total"],collège['taux_decrochage'])
print('Coefficient de Corrélation de Pearson : r=', correlation)
print('p-value:', p_value)
# Out:
# Coefficient de Corrélation de Pearson : r= -0.24987807505380238
# p-value: 1.890615013774513e-63

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
# <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# ➜<u><b>Conclusion:</b></u></br>
# Puisque la p-value est très petite, nous rejetons l'hypothèse nulle (H0). Cela signifie que les données fournissent suffisamment de preuves pour conclure qu'il existe une corrélation statistiquement significative entre la taille du collège et le taux de décrochage.
# </br>En résumé, nous rejetons l'hypothèse nulle et acceptons l'hypothèse alternative, ce qui indique qu'il y a bien une corrélation (bien que faible et négative) entre la taille du collège et le taux de décrochage.
# </p></div>

# %% [markdown]
# <a id='Question3'></a>
# ### <div style="background-color:#C8AD7F;font-family:newtimeroman;color:#333333;font-size:150%;text-align:center;border-radius:10px 10px;">Est-ce la même conclusion pour les garçons que pour les filles ?</div>

# %%
# Calcul du nombre de décrocheurs pour les filles et les garçons
df_selection['taux_décrochage_filles']=(df_selection['6èmes filles'] -df_selection['3èmes filles'])/df_selection['6èmes filles']*100
df_selection['taux_décrochage_garçons']=(df_selection['6èmes garçons'] - df_selection['3èmes garçons'])/df_selection['6èmes garçons']*100
df_selection
# Out:
#        Rentrée scolaire Numéro du collège  Nombre d'élèves total  6èmes total  \
# 0                  2019          0691664J                    779          208
# 1                  2019          0692390Y                     59           15
# 2                  2019          0693093M                    450           93
# 3                  2019          0694296V                    398          124
# 4                  2019          0690117C                    432          115
# ...                 ...               ...                    ...          ...
# 32977              2020          0352071L                    159           38
# 32978              2020          0350780H                    892          212
# 32979              2020          0350887Z                    231           49
# 32980              2020          0561399S                    315           80
# 32981              2020          0560136U                    655          159
#
# ...

# %%
print("Valeurs infinies (inf) :")
print(df_selection[df_selection.isin([np.inf, -np.inf]).any(axis=1)])

# Vérification des valeurs manquantes (NaN)
print("Valeurs manquantes (NaN) :")
print(df_selection[df_selection.isnull().any(axis=1)])
# Out:
# Valeurs infinies (inf) :
#        Rentrée scolaire Numéro du collège  Nombre d'élèves total  6èmes total  \
# 14                 2019          0251349F                     26            0
# 23                 2019          0700011G                     23            0
# 26                 2019          0700038L                     24            0
# 34                 2019          0390786T                     15            0
# 39                 2019          0900236T                     24            0
# ...                 ...               ...                    ...          ...
# 32943              2020          0290130J                     16            0
# 32952              2020          0290078C                     24            0
# 32969              2020          0350790U                     11            0
# 32971              2020          0350032V                     24            0
# 32976              2020          0351878B                     24            0
#
# ...

# %%
# Remplacer les valeurs manquantes par la moyenne
df_selection['taux_décrochage_garçons'].fillna(df_selection['taux_décrochage_garçons'].mean(), inplace=True)

# %%
# Remplacer les valeurs manquantes par la moyenne
df_selection['taux_décrochage_filles'].fillna(df_selection['taux_décrochage_filles'].mean(), inplace=True)

# %%
df=df_selection[(df_selection['taux_décrochage_filles']>=0) & (df_selection['taux_décrochage_garçons']>=0)]

# %%
# Calcul des moyennes des taux de décrochage pour les filles et les garçons
taux_décrochage_filles = df['taux_décrochage_filles'].mean()
taux_décrochage_garçons = df['taux_décrochage_garçons'].mean()

# %%
print(" le taux de décrochage des filles est :",taux_décrochage_filles)
# Out:
#  le taux de décrochage des filles est : 17.133202133016614

# %%
print(" le taux de décrochage des garçon est :",taux_décrochage_garçons)
# Out:
#  le taux de décrochage des garçon est : 18.714904721866624

# %%
# Tracé du graphique
plt.figure(figsize=(8, 6))
sns.barplot(x=['Filles', 'Garçons'], y=[taux_décrochage_filles, taux_décrochage_garçons])
plt.title('Comparaison des Taux de Décrochage moyen entre Filles et Garçons')
plt.xlabel('Groupe')
plt.ylabel('Taux de Décrochage')
plt.show()

# %% [markdown]
# ### Le test t de Student

# %% [markdown]
# le test t de student est utilisé pour comparer les moyennes de deux échantillons indépendants et déterminer s'il existe une différence statistiquement significative entre ces moyennes.
# </br>Dans ce cas, vous comparez le taux de décrochage scolaire entre les garçons et les filles.
# <u>hypothèse nulle :</u> il n'y a pas de différence significative entre les taux de décrochage des garçons et des filles.</br>
# <u>hypothèse alternative :</u> il y a différence significative entre les taux de décrochage des garçons et des filles

# %%
# Test t de Student pour comparer les moyennes
t_statistic, p_value = stats.ttest_ind(df['taux_décrochage_garçons'], df['taux_décrochage_filles'])

# Affichage des résultats
print('Test t de Student :')
print('Statistic t :', t_statistic)
print('p-value :', p_value)
# Out:
# Test t de Student :
# Statistic t : 7.365138949626577
# p-value : 1.8388215796875454e-13

# %% [markdown]
# <b>Statistique t</b></br>
# Le résultat de la statistique t est 7.365138949626577. Ce nombre indique à quel point les moyennes des échantillons des garçons et des filles diffèrent en termes d'unités d'écart-type. Plus le nombre est grand en valeur absolue, plus la différence entre les groupes est significative.

# %% [markdown]
# <b>p-value</b></br>
# Le p-value est 1.8388215796875454e-13, ce qui est extrêmement petit. Cela signifie que la probabilité d'observer une différence aussi importante entre les moyennes des taux de décrochage des garçons et des filles, simplement en raison du hasard (sous l'hypothèse nulle que les moyennes sont égales), est très faible.

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
# <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# <b>Interprétation</b></br>
# Étant donné que le p-value est bien inférieur à la plupart des seuils de significativité couramment utilisés (comme 0.05 ou 0.01), on peut rejeter l'hypothèse nulle selon laquelle il n'y a pas de différence significative entre les taux de décrochage des garçons et des filles
# </p></div>

# %% [markdown]
# <a id='Question4'></a>
# ### <div style="background-color:#C8AD7F;font-family:newtimeroman;color:#333333;font-size:150%;text-align:center;border-radius:10px 10px;">Est-ce que le constat change en fonction de la région ?</div>

# %% [markdown]
# ##### a. Préparation et visualisation des données

# %%
region = df_selection[df_selection['taux_decrochage'] != -np.inf]
region = df_selection[ df_selection['taux_decrochage'] >= 0]

# %%
somme_par_region = region.groupby('Région')['taux_decrochage'].mean()
somme_par_region=somme_par_region.reset_index()
somme_par_region
# Out:
#                         Région  taux_decrochage
# 0      AUVERGNE-ET-RHONE-ALPES        13.671009
# 1   BOURGOGNE-ET-FRANCHE-COMTE        14.324855
# 2                     BRETAGNE        15.634800
# 3          CENTRE-VAL-DE-LOIRE        13.581538
# 4                        CORSE        13.021725
# 5                    GRAND-EST        13.063521
# 6                   GUADELOUPE        10.215487
# 7                       GUYANE        11.895696
# 8              HAUTS-DE-FRANCE        13.363540
# 9                ILE-DE-FRANCE        11.023289
# 10                  LA-REUNION        12.261529
# 11                  MARTINIQUE        11.570116
# 12                     MAYOTTE        10.275961
# 13                   NORMANDIE        14.359023
# 14          NOUVELLE-AQUITAINE        14.193757
# 15                   OCCITANIE        14.731803
# 16            PAYS-DE-LA-LOIRE        15.190249
# 17  PROVENCE-ALPES-COTE-D'AZUR        12.039013

# %%
# Visualisation des taux de décrocheurs par région
sns.barplot(x='Région', y='taux_decrochage', data=somme_par_region)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### ANOVA
# 1. Hypothèse nulle (H0): Les taux de décrochage moyens sont égaux pour toutes les régions.
# 2. Hypothèse alternative (H1): Au moins une région a un taux de décrochage moyen différent.

# %%
groupes = [region[region['Région'] == nom]['taux_decrochage'] for nom in region['Région'].unique()]
# Effectuer l'ANOVA
f_value, p_value = stats.f_oneway(*groupes)
print('Résultats de l\'ANOVA :')
print('F-value:', f_value)
print('p-value:', p_value)
# Out:
# Résultats de l'ANOVA :
# F-value: 13.493789018190991
# p-value: 6.400800480432926e-39

# %% [markdown]
# <b>P-value très faible :</b></br> La p-value très faible (6.4×10−396.4×10 −39) indique qu'il y a des preuves extrêmement solides pour rejeter l'hypothèse nulle. Cela signifie qu'il est très improbable que les différences observées entre les taux de décrochage des régions soient dues au hasard. En d'autres termes, au moins une région a un taux de décrochage moyen significativement différent des autres.

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342">
# <p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# ╰┈➤ On rejette l'hypothèse nulle.
# </p></div>

# %% [markdown]
# <a id='Question5'></a>
# ### <div style="background-color:#C8AD7F;font-family:newtimeroman;color:#333333;font-size:150%;text-align:center;border-radius:10px 10px;">Y-a-t'il un lien avec le fait d'être en collège public ou privé ?</div>

# %% [markdown]
# <b>a. visualisation les données:</b>

# %%
Secteur0 = df_selection[df_selection['taux_decrochage'] != -np.inf]
Secteur0 = df_selection[ df_selection['taux_decrochage'] >= 0]

# %%
secteur = Secteur0.groupby('Secteur')['taux_decrochage'].mean()
secteur=secteur.reset_index()
secteur
# Out:
#   Secteur  taux_decrochage
# 0   PRIVE        15.371799
# 1  PUBLIC        12.701461

# %%
sns.barplot(x='Secteur', y='taux_decrochage', data=secteur)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <b>b. Test t de Student pour comparer public vs privé</b></br>
# <u>Hypothèses du Test :</u>
# * Hypothèse nulle (H0) : Les taux de décrochage moyens des collèges publics et privés sont égaux.
# * Hypothèse alternative (H1) : Les taux de décrochage moyens des collèges publics et privés sont différents.

# %%
# Test t de Student pour comparer public vs privé
public =Secteur0[Secteur0['Secteur'] == 'PUBLIC']['taux_decrochage']
privé = Secteur0[Secteur0['Secteur'] == 'PRIVE']['taux_decrochage']
t_stat, p_val = stats.ttest_ind(public, privé)
print(f"t-statistic: {t_stat}, p-value: {p_val}")
# Out:
# t-statistic: -13.075956275167039, p-value: 6.947147334752173e-39

# %% [markdown]
# <b>Valeur de la t-statistique :</b></br>
# La valeur négative de la t-statistique (-13.075) indique que le taux de décrochage moyen des collèges publics est inférieur à celui des collèges privés. La magnitude élevée de cette valeur (en absolu) montre une grande différence entre les deux moyennes.

# %% [markdown]
# <b>p-value :</b></br>
# La p-value extrêmement faible (bien en dessous du seuil de signification de 0.05) indique que la différence observée entre les taux de décrochage des collèges publics et privés est très peu probable due au hasard.

# %% [markdown]
# <b>c. Conclusion: </b>

# %% [markdown]
# <div style="background-color:#ebebe8;font-family:newtimeroman; padding: 20px; border-radius: 10px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);border:2px solid #0A2342"><p style="font-size:20px;  line-height: 1.5em; text-indent: 20px;">
# </br><u>Rejet de l'hypothèse nulle (H0) :</u> Étant donné que la p-value est bien inférieure à 0.05, nous rejetons l'hypothèse nulle. Cela signifie qu'il y a des preuves statistiques significatives pour dire que les taux de décrochage moyens des collèges publics et privés sont différents.
# </p></div>

# %% [markdown]
# <a id='FIN'></a>
# # <div style="background-color:#682F2F;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">FIN [⬆️](#TabMatiere)</div>
